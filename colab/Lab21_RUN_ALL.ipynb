# %% [markdown]
# # Lab 21 — Fine-tuning LLMs · RUN ALL (T4)
#
# Chay tu tren xuong. Runtime > Change runtime type > **T4 GPU** truoc khi bat dau.
#
# | O | Lam gi | Thoi gian |
# |---|---|---|
# | 1 | clone + install | ~1 phut |
# | 2 | smoke: import + unit test | ~30 giay |
# | 3 | **core pipeline NB1 -> NB5** | ~80 phut |
# | 4 | gatekeeper + in ket qua | ~10 giay |

# %%
# @title 1. Setup — clone + install (chạy ô này trước)
import os, subprocess, sys

REPO = "https://github.com/ddhung04/Day21-Track3-Finetuning-Lab_2A202601166_DaoDuyHung.git"
REPO_DIR = "Day21-Track3-Finetuning-Lab_2A202601166_DaoDuyHung"
if not os.path.exists(REPO_DIR):
    subprocess.run(["git", "clone", "-q", REPO], check=True)
os.chdir(f"/content/{REPO_DIR}")
subprocess.run(["git", "pull", "-q"], check=False)
sys.path.insert(0, "src")

# Install from requirements.txt, NOT a copied list. The copied list is how the
# torchao>=0.16 pin reached requirements.txt and this bootstrap on different days --
# and a bootstrap missing a pin does not fail here, it fails 10 minutes later inside
# get_peft_model(). One source of truth. torch is preinstalled on Colab and
# requirements.txt pins it compatibly, so that line is a no-op.
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"],
               check=True)

import torch
print("commit :", subprocess.run(["git","rev-parse","--short","HEAD"],
                                 capture_output=True, text=True).stdout.strip())
print("GPU    :", torch.cuda.get_device_name(0) if torch.cuda.is_available()
      else "NONE — Runtime > Change runtime type > T4 GPU")
if torch.cuda.is_available():
    print("VRAM   : %.1f GB" % (torch.cuda.get_device_properties(0).total_memory/1024**3))
# Out:
# commit : 811263e
# GPU    : Tesla T4
# VRAM   : 14.6 GB

# %%
# @title 2. Smoke — imports, seed data, unit tests (no GPU needed)
# !python scripts/verify.py --smoke
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.34s
#
# 6 passed · 0 warnings · 1 failures
#
# Not ready to submit — fix the FAILs above.

# %%
# @title 3. Core pipeline — NB1 → NB5
# EVAL_LIMIT truncates both eval sets: "" = full run (submittable),
# 8 = ~fast smoke pass. STAGES lets you resume after a failure.
import os
COMPUTE_TIER = "T4"        # @param ["CPU","LAPTOP","T4","BIGGPU"]
EVAL_LIMIT   = ""          # @param ["", "4", "8", "16", "25"]
STAGES       = "nb1 nb2 nb3 nb4 nb5"   # @param {type:"string"}

os.environ["COMPUTE_TIER"] = COMPUTE_TIER
if EVAL_LIMIT:
    os.environ["EVAL_LIMIT"] = EVAL_LIMIT
else:
    os.environ.pop("EVAL_LIMIT", None)

from labkit import device
print(device.banner(), "\n")

# !python scripts/colab_run.py {STAGES}
# Out:
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
#
# tier=T4  mask=assistant-only  eval_limit=full
#
# ========================================================================
# NB1 — data, chat template & loss mask
# ========================================================================
# tier=T4  model=unsloth/Qwen3.5-4B  max_length=1024
# 250 mẫu huấn luyện
# {
#   "instruction": "Phân loại ticket chăm sóc khách hàng sau thành JSON với đúng 4 khóa: intent, urgency, product, sentiment. Chỉ trả về JSON, không giải thích.\n\nintent thuộc: doi_tra | van_chuyen | hoan_tien | san_pham_loi | hoi_thong_tin\nurgency thuộc: cao | trung_binh | thap\nsentiment thuộc: tieu_cuc | trung_tinh | tich_cuc\nproduct: tên sản phẩm xuất hiện trong ticket.",
#   "input": "Alo sh
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 2.76k/2.76k [00:00<00:00, 9.44MB/s]
# tokenizer_config.json: 100% 15.7k/15.7k [00:00<00:00, 40.6MB/s]
# vocab.json: 100% 5.23M/5.23M [00:00<00:00, 87.3MB/s]
# merges.txt: 100% 3.35M/3.35M [00:00<00:00, 119MB/s]
#
# tokenizer.json: downloading bytes:  11% 2.23M/20.0M [00:00<00:04, 4.35MB/s, 12.3kB/s  ]
# tokenizer.json: downloading bytes: 100% 6.23M/6.23M [00:00<00:00, 8.49MB/s,  614kB/s  ]
# tokenizer.json: reconstructing file: 100% 20.0M/20.0M [00:00<00:00, 27.2MB/s, 1.97MB/s  ]
# added_tokens.json: 100% 904/904 [00:00<00:00, 4.49MB/s]
# special_tokens_map.json: 100% 876/876 [00:00<00:00, 4.86MB/s]
# chat_template.jinja: 100% 7.99k/7.99k [00:00<00:00, 16.4MB/s]
# eos_token: <|im_end|>
# VERDICT: reasoning preserved — safe to train on traces
#
# --- chuỗi đã render ---
# <|im_start|>user
# 2+2?<|im_end|>
# <|im_start|>assistant
# <think>
# buoc 1: kiem tra. buoc 2: tra loi.
# </think>
#
# 4<|im_end|>
#
# ======================================================================
# mode = assistant-only   supervised 39/94 (41%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# ======================================================================
# mode = everything   supervised 94/94 (100%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# <|im_start|>system
# Phân loại ticket sau.<|im_end|>
# <|im_start|>user
# Alo shop, mình đặt balo laptop mã đơn VN411453. Cho tôi trả lại. Đã 3 ngày rồi. Cho tôi hỏi.<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# {
#   "mask_mode": "assistant-only",
#   "n_supervised": 39,
#   "n_total": 94,
#   "supervised_fraction": 0.4149,
#   "answer_is_supervised": true,
#   "question_is_masked": true
# }
# {
#   "n": 250,
#   "mean": 93.1,
#   "p50": 93,
#   "p95": 98,
#   "p99": 100,
#   "max": 101,
#   "suggested_max_length": 256
# }
#
# ⚠ p95 gợi ý max_length=256 nhưng tier đang đặt 1024. Ghi lại lựa chọn của bạn trong REPORT.md.
# train=225  val=25  -> /content/Day21-Track3-Finetuning-Lab_2A202601166_DaoDuyHung/data/split
#
# -- NB1 ok in 20s
#
# ========================================================================
# NB2 — freeze eval + three baselines
# ========================================================================
# target=50  regression=15  tier=T4
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# model.safetensors.index.json: 100% 76.2k/76.2k [00:00<00:00, 149MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/5.33G [00:00<?, ?B/s]
# Downloading bytes:   1% 59.4M/9.32G [00:00<01:58, 78.4MB/s, 33.7MB/s  ]
# Downloading bytes:   2% 201M/9.32G [00:01<00:45, 199MB/s,  219MB/s  ]
# Downloading bytes:   3% 304M/9.32G [00:01<00:47, 189MB/s,  216MB/s  ]
# Downloading bytes:   4% 342M/9.32G [00:02<00:48, 185MB/s,  189MB/s  ]
# Downloading bytes:   8% 745M/9.32G [00:03<00:25, 332MB/s,  317MB/s  ]
# Downloading bytes:   9% 841M/9.32G [00:04<00:38, 222MB/s,  284MB/s  ]
# Downloading bytes:  11% 1.06G/9.32G [00:05<00:37, 223MB/s,  256MB/s  ]
# Downloading bytes:  12% 1.13G/9.32G [00:05<00:47, 174MB/s,  183MB/s  ]
# Downloading bytes:  15% 1.36G/9.32G [00:06<00:47, 168MB/s,  180MB/s  ]
# Downloading bytes:  16% 1.48G/9.32G [00:07<00:38, 205MB/s,  242MB/s  ]
# Downloading bytes:  23% 2.16G/9.32G [00:10<00:37, 190MB/s,  222MB/s  ]
# Downloading bytes:  29% 2.67G/9.32G [00:13<00:47, 139MB/s,  155MB/s  ]
# Downloading bytes:  29% 2.71G/9.32G [00:13<00:51, 127MB/s,  142MB/s  ]
# Downloading bytes:  30% 2.84G/9.32G [00:14<00:38, 170MB/s,  196MB/s  ]
# Downloading bytes:  31% 2.92G/9.32G [00:14<00:32, 195MB/s,  176MB/s  ]
# Downloading bytes:  33% 3.09G/9.32G [00:15<00:32, 192MB/s,  176MB/s  ]
# Downloading bytes:  33% 3.12G/9.32G [00:16<00:34, 180MB/s,  192MB/s  ]
# Downloading bytes:  40% 3.75G/9.32G [00:18<00:20, 270MB/s,  262MB/s  ]
# Downloading bytes:  42% 3.93G/9.32G [00:19<00:23, 226MB/s,  206MB/s  ]
# Downloading bytes:  53% 4.91G/9.32G [00:23<00:15, 290MB/s,  267MB/s  ]
# Downloading bytes:  53% 4.94G/9.32G [00:26<02:22, 30.8MB/s,  290MB/s  ]
# Downloading bytes:  55% 5.11G/9.32G [00:28<00:34, 123MB/s,  108MB/s  ]
# Downloading bytes:  57% 5.34G/9.32G [00:29<00:26, 149MB/s,  134MB/s  ]
# Downloading bytes:  58% 5.43G/9.32G [00:30<00:24, 157MB/s,  159MB/s  ]
# Downloading bytes:  61% 5.64G/9.32G [00:31<00:25, 144MB/s,  163MB/s  ]
# Downloading bytes:  61% 5.68G/9.32G [00:31<00:24, 149MB/s,  146MB/s  ]
# Downloading bytes:  69% 6.44G/9.32G [00:34<00:09, 301MB/s,  333MB/s  ]
# Downloading bytes:  70% 6.50G/9.32G [00:35<00:15, 186MB/s,  243MB/s  ]
# Downloading bytes:  76% 7.07G/9.32G [00:37<00:12, 184MB/s,  192MB/s  ]
# Downloading bytes:  76% 7.11G/9.32G [00:39<00:34, 63.5MB/s, 57.5MB/s  ]
# Downloading bytes:  78% 7.26G/9.32G [00:40<00:13, 156MB/s,  162MB/s  ]
# Downloading bytes:  80% 7.47G/9.32G [00:46<00:19, 96.0MB/s, 79.2MB/s  ]
# Downloading bytes:  86% 8.04G/9.32G [00:52<00:07, 174MB/s,  217MB/s  ]
# Reconstructing (incomplete total...):  69% 6.48G/9.32G [00:55<00:37, 76.0MB/s, 69.8MB/s  ]
# Reconstructing (incomplete total...):  72% 6.74G/9.32G [01:04<00:48, 53.5MB/s, 76.0MB/s  ]
# Reconstructing (incomplete total...):  78% 7.24G/9.32G [01:07<00:28, 74.0MB/s, 53.5MB/s  ]
# Reconstructing (incomplete total...):  80% 7.44G/9.32G [01:07<00:20, 91.0MB/s, 74.0MB/s  ]
#
# Downloading bytes:  86% 8.05G/9.32G [01:09<00:07, 174MB/s,  174MB/s  ]
# Reconstructing (incomplete total...):  85% 7.89G/9.32G [01:11<00:14, 98.8MB/s, 91.0MB/s  ]
# Reconstructing (incomplete total...):  88% 8.24G/9.32G [01:14<00:09, 109MB/s, 98.8MB/s  ]
# Reconstructing (incomplete total...):  91% 8.49G/9.32G [01:15<00:06, 125MB/s,  109MB/s  ]
# Reconstructing (incomplete total...):  94% 8.76G/9.32G [01:17<00:04, 116MB/s,  125MB/s  ]
# Reconstructing (incomplete total...):  97% 9.04G/9.32G [01:18<00:02, 137MB/s,  116MB/s  ]
# Reconstructing (incomplete total...):  99% 9.22G/9.32G [01:19<00:00, 151MB/s,  137MB/s  ]
# Reconstructing (incomplete total...): 100% 9.31G/9.32G [01:21<00:00, 112MB/s,  151MB/s  ]
#
# Fetching 2 files: 100% 2/2 [01:21<00:00, 40.95s/it]
# Download complete: 100% 8.05G/8.05G [01:21<00:00, 174MB/s,  174MB/s  ]
# Download complete: 100% 8.05G/8.05G [01:22<00:00, 98.2MB/s,  174MB/s  ]
# Reconstruction complete: 100% 9.32G/9.32G [01:22<00:00, 114MB/s,  112MB/s  ]
# Loading weights: 100% 426/426 [00:31<00:00, 13.56it/s]
#   [(a) base + naive prompt/target] batch 1/13     14s elapsed  ~  174s left
#   [(a) base + naive prompt/target] batch 2/13     27s elapsed  ~  147s left
#   [(a) base + naive prompt/target] batch 3/13     39s elapsed  ~  129s left
#   [(a) base + naive prompt/target] batch 4/13     51s elapsed  ~  114s left
#   [(a) base + naive prompt/target] batch 5/13     63s elapsed  ~  100s left
#   [(a) base + naive prompt/target] batch 6/13     75s elapsed  ~   88s left
#   [(a) base + naive prompt/target] batch 7/13     87s elapsed  ~   75s left
#   [(a) base + naive prompt/target] batch 8/13     99s elapsed  ~   62s left
#   [(a) base + naive prompt/target] batch 9/13    111s elapsed  ~   49s left
#   [(a) base + naive prompt/target] batch 10/13    123s elapsed  ~   37s left
#   [(a) base + naive prompt/target] batch 11/13    135s elapsed  ~   24s left
#   [(a) base + naive prompt/target] batch 12/13    147s elapsed  ~   12s left
#   [(a) base + naive prompt/target] batch 13/13    159s elapsed  ~    0s left
#   [(a) base + naive prompt/target] done: 50 prompts in 159s
#   [(a) base + naive prompt/regression] batch 1/4      6s elapsed  ~   17s left
#   [(a) base + naive prompt/regression] batch 2/4     12s elapsed  ~   12s left
#   [(a) base + naive prompt/regression] batch 3/4     20s elapsed  ~    7s left
#   [(a) base + naive prompt/regression] batch 4/4     27s elapsed  ~    0s left
#   [(a) base + naive prompt/regression] done: 15 prompts in 27s
# (a) base + naive prompt      target=0.000  regression=0.758  format=0.000  3173ms
#   [(b) base + optimized prompt/target] batch 1/13      5s elapsed  ~   55s left
#   [(b) base + optimized prompt/target] batch 2/13      9s elapsed  ~   47s left
#   [(b) base + optimized prompt/target] batch 3/13     12s elapsed  ~   41s left
#   [(b) base + optimized prompt/target] batch 4/13     17s elapsed  ~   37s left
#   [(b) base + optimized prompt/target] batch 5/13     21s elapsed  ~   33s left
#   [(b) base + optimized prompt/target] batch 6/13     25s elapsed  ~   29s left
#   [(b) base + optimized prompt/target] batch 7/13     29s elapsed  ~   25s left
#   [(b) base + optimized prompt/target] batch 8/13     32s elapsed  ~   20s left
#   [(b) base + optimized prompt/target] batch 9/13     36s elapsed  ~   16s left
#   [(b) base + optimized prompt/target] batch 10/13     41s elapsed  ~   12s left
#   [(b) base + optimized prompt/target] batch 11/13     45s elapsed  ~    8s left
#   [(b) base + optimized prompt/target] batch 12/13     49s elapsed  ~    4s left
#   [(b) base + optimized prompt/target] batch 13/13     53s elapsed  ~    0s left
#   [(b) base + optimized prompt/target] done: 50 prompts in 53s
#   [(b) base + optimized prompt/regression] batch 1/4      5s elapsed  ~   14s left
#   [(b) base + optimized prompt/regression] batch 2/4     12s elapsed  ~   12s left
#   [(b) base + optimized prompt/regression] batch 3/4     19s elapsed  ~    6s left
#   [(b) base + optimized prompt/regression] batch 4/4     26s elapsed  ~    0s left
#   [(b) base + optimized prompt/regression] done: 15 prompts in 26s
# (b) base + optimized prompt  target=0.765  regression=0.758  format=1.000  1051ms
# {
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "baseline_a": {
#     "target": 0.0,
#     "regression": 0.7577777777777778,
#     "format": 0.0,
#     "latency_ms": 3172.7201876399945,
#     "n": 50,
#     "extra": {}
#   },
#   "baseline_b": {
#     "target": 0.765,
#     "regression": 0.7577777777777778,
#     "format": 1.0,
#     "latency_ms": 1051.2208573999987,
#     "n": 50,
#     "extra": {}
#   },
#   "optimized_prompt_sha": "719e74d3b6232053",
#   "n_target": 50,
#   "n_regression": 15,
#   "eval_limit": null,
#   "smoke_mode": false
# }
#
# -- NB2 ok in 394s
#
# ========================================================================
# NB3 — train the correct configuration
# ========================================================================
# T4 · unsloth/Qwen3.5-4B · all-linear · r=16 · LR 10x · 16-bit
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1163.31it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.77it/s]
# {
#   "num_hidden_layers": 32,
#   "full_attention_interval": 4,
#   "linear_num_key_heads": 16,
#   "layer_types": {
#     "linear_attention": 24,
#     "full_attention": 8
#   }
# }
# placement=text-linear  modules=['down_proj', 'gate_proj', 'in_proj_a', 'in_proj_b', 'in_proj_qkv', 'in_proj_z', 'k_proj', 'o_proj', 'out_proj', 'q_proj', 'up_proj', 'v_proj']
# trainable LoRA params ≈ 32.46 M
#     {'placement': 'text-linear', 'modules': 12, 'r': 16, 'trainable': 32464896}
#     {'placement': 'attn-only(q,v)', 'modules': 2, 'r': 16, 'trainable': 1835008}
#     {'placement': 'attn-only(q,v) matched', 'modules': 2, 'r': 283, 'trainable': 32456704}
# Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
# mask_mode = assistant-only   supervised 9014/20951 tokens (43.0%)
# epochs=2.0  ->  30 optimizer steps  (NB4 runs its contrasts at exactly this many)
# {
#   "output_dir": "/content/Day21-Track3-Finetuning-Lab_2A202601166_DaoDuyHung/adapters/correct",
#   "max_length": "1024",
#   "per_device_train_batch_size": "1",
#   "gradient_accumulation_steps": "16",
#   "learning_rate": "0.0001",
#   "lr_scheduler_type": "cosine",
#   "num_train_epochs": "2.0",
#   "logging_steps": "5",
#   "save_strategy": "no",
#   "report_to": "none",
#   "seed": "42",
#   "packing": "False",
#   "loss_type": "chunked_nll",
#   "gradient_checkpointing": "True",
#   "warmup_steps": "3",
#   "bf16": "False",
#   "fp16": "True",
#   "padding_free": "False"
# }
# Truncating train dataset: 100% 225/225 [00:00<00:00, 3188.41 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 19462.53 examples/s]
# precision fix: {'precision': 'fp16', 'recast': 0, 'trainable_tensors': 496}
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
#  23% 7/30 [04:10<13:28, 35.14s/it]

# %%
  # @title 4. Gatekeeper + results + tải ZIP
  # !python scripts/verify.py

  print("\n================ results/ ================")
  # !ls -la results/
  # !echo && echo "---- runs.csv ----" && cat results/runs.csv 2>/dev/null  !echo && echo "---- verdict.json ----" && cat results/verdict.json 2>/  dev/null

  # Đóng gói artefact để tải một lần
  # !rm -f /content/lab21_submission_artifacts.zip
  # !zip -qr /content/lab21_submission_artifacts.zip results adapters/
  correct submission/REPORT.md

  print("\nZIP ready: /content/lab21_submission_artifacts.zip")
  from google.colab import files
  files.download("/content/lab21_submission_artifacts.zip")
